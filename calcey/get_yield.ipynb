# %%
import pandas as pd

# %%
df = pd.read_csv("../data/FAOSTAT_data_en_5-22-2024.csv")
df
# Out:
#       Domain Code                        Domain  Area Code (M49)         Area  \
# 0             QCL  Crops and livestock products                4  Afghanistan
# 1             QCL  Crops and livestock products                4  Afghanistan
# 2             QCL  Crops and livestock products                4  Afghanistan
# 3             QCL  Crops and livestock products                4  Afghanistan
# 4             QCL  Crops and livestock products                4  Afghanistan
# ...           ...                           ...              ...          ...
# 44573         QCL  Crops and livestock products              716     Zimbabwe
# 44574         QCL  Crops and livestock products              716     Zimbabwe
# 44575         QCL  Crops and livestock products              716     Zimbabwe
# 44576         QCL  Crops and livestock products              716     Zimbabwe
# 44577         QCL  Crops and livestock products              716     Zimbabwe
#
# ...

# %%
country_list = df['Area'].unique()

# %%
df = pd.DataFrame(country_list)
df.to_csv('FAO_country_list.csv', index=False)
